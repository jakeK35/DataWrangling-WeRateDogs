# %% [markdown]
# #  Analysis and Insights of Twitter 'WeRateDogs'

# %% [markdown]
# ## Number of tweet changed over time

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tweets of WeRateDogs has been since November 2015, The number of tweets was about 25 per day
# It had been decreased steadily and sharply. It couldn't be over 5 since March 2017.

# %% [markdown]
# ## Relationship between the number of retweet and favorive

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Retween count of the tweet is in proportion to favorite count ,cosidering the linear regression plot.
# Given the slope of the line, favorite count is usually higher thant retween count.
# There are small portion of data where favorite is over 40,000 and retweet is over 20,000,

# %% [markdown]
# ## Top 10 dogs breed most exsisting in tweets based on prediction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Golden Retriever is most popular dog breed
# Labrador Retriever ,a genetically very similar with Golden Retriever, is 2nd breed.
# It show that Retrievers is very popular to people
